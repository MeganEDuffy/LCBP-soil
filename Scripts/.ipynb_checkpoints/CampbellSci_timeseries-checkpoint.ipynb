# %%
# Plotting timeseries from Campbell Sci datafiles that MED downloaded in September 2025
source("/home/millieginty/OneDrive/git-repos/LCBP_Soils/Functions/CampbellSciImport.R")

# Define your paths
raw_path <- "~//OneDrive/git-repos/LCBP_Soils/OriginalData/soil-sensors/NEWRNET_raw_data/"
clean_path <- "~//OneDrive/git-repos/LCBP_Soils/CleanedData/soil-sensors/BREE_WY25/"

# Run the function
process_soil_sensors(input_dir = raw_path, output_dir = clean_path)

# Check the workspace
# Sould see objects like: HD1_79113_Table1, WW2_80224_Table1, etc.
head(HD1_79113_Table1)
# Out:
# Processed and assigned: HD1_79113_Table1
#
# Processed and assigned: HW1_84984_Table1
#
# Processed and assigned: HW2_78920_Table1
#
# Processed and assigned: WD1_79124_Table1
#
# Processed and assigned: WD1_79124_Table2
#
# Processed and assigned: WD2_79121_Table1
#
# Processed and assigned: WD2_79121_Table1
#
# Processed and assigned: WD3_79133_Table1
#
# Processed and assigned: WD3_79133_Table2
#
# Processed and assigned: WW1_79118_Table1
#
# Processed and assigned: WW1_79118_Table1
#
# Processed and assigned: WW5_79129_Table1
#
# Processed and assigned: WW5_79129_Table2
#
# Processed and assigned: WW6_79122_Table1
#
# Processed and assigned: WW6_79122_Table2
#
# Processed and assigned: WW8_79120_Table1
#
# Processed and assigned: WW8_79120_Table2
#   TIMESTAMP           RECORD O2_mV_Avg(1) O2_mV_Avg(2) O2_mV_Avg(3)
# 1 2024-07-01 01:30:00 218251 43.68412     39.32171     43.36328
# 2 2024-07-01 01:45:00 218252 43.63083     39.35005     43.36328
# ...

# %%
# 1. Define range and output path (if needed, NULL is okay)

event_window <- as.POSIXct(c("2025-02-10", "2025-02-25"), tz = "UTC")
plots_path <- "~//OneDrive/git-repos/LCBP_Soils/Plots/"

# 2. Run and save as jpg

hd1_plot <- plot_soil_sensors(
  df = HD1_79113_Table1, 
  df_name = "HD1_79113_Table1",
  sensor_types = c("VWC", "O2_Final_Avg", "SBTemp_C_Avg", "EC"), 
  time_range = event_window,
  output_dir = plots_path
)

print(hd1_plot)
# Out:
# Warning message:
# “Removed 1921 rows containing missing values or values outside the scale range (`geom_line()`).”
# Saved: HD1_79113_Table1_VWC_O2_Final_Avg_SBTemp_C_Avg_EC.jpg to ~//OneDrive/git-repos/LCBP_Soils/Plots/
#
# Warning message:
# “Removed 1921 rows containing missing values or values outside the scale range (`geom_line()`).”
# plot without title

# %%
# 1. Define range and output path (if needed, NULL is okay)

event_window <- as.POSIXct(c("2022-02-10", "2025-02-25"), tz = "UTC")
plots_path <- "~//OneDrive/git-repos/LCBP_Soils/Plots/"

# 2. Run and save as jpg

wd1_plot <- plot_soil_sensors(
  df = WD1_79124_Table1, 
  df_name = "WD1_79124_Table1",
  sensor_types = c("VWC", "O2_Final_Avg", "SBTemp_C_Avg", "EC"), 
  time_range = event_window,
  output_dir = plots_path
)

print(wd1_plot)
# Out:
# Saved: WD1_79124_Table1_VWC_O2_Final_Avg_SBTemp_C_Avg_EC.jpg to ~//OneDrive/git-repos/LCBP_Soils/Plots/
# plot without title

# %%
# 1. Define range and output path (if needed, NULL is okay)

event_window <- as.POSIXct(c("2022-02-10", "2025-02-25"), tz = "UTC")
plots_path <- "~//OneDrive/git-repos/LCBP_Soils/Plots/"

# 2. Run and save as jpg

wd2_plot <- plot_soil_sensors(
  df = WD2_79121_Table1, 
  df_name = "WD2_79121_Table1",
  sensor_types = c("VWC", "O2_Final_Avg", "SBTemp_C_Avg", "EC"), 
  time_range = event_window,
  output_dir = plots_path
)

print(wd2_plot)
# Out:
# Warning message:
# “Removed 41096 rows containing missing values or values outside the scale range (`geom_line()`).”
# Saved: WD2_79121_Table1_VWC_O2_Final_Avg_SBTemp_C_Avg_EC.jpg to ~//OneDrive/git-repos/LCBP_Soils/Plots/
#
# Warning message:
# “Removed 41096 rows containing missing values or values outside the scale range (`geom_line()`).”
# plot without title

# %%
# 1. Define range and output path (if needed, NULL is okay)

event_window <- as.POSIXct(c("2022-02-10", "2026-02-25"), tz = "UTC")
plots_path <- "~//OneDrive/git-repos/LCBP_Soils/Plots/"

# 2. Run and save as jpg

hw1_plot <- plot_soil_sensors(
  df = HW1_84984_Table1, 
  df_name = "HW1_84984_Table1",
  sensor_types = c("VWC", "O2_Final_Avg", "SBTemp_C_Avg", "EC"), 
  time_range = event_window,
  output_dir = plots_path
)

print(hw1_plot)
# Out:
# Warning message:
# “Removed 1794 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1794 rows containing missing values or values outside the scale range (`geom_line()`).”
# Saved: HW1_84984_Table1_VWC_O2_Final_Avg_SBTemp_C_Avg_EC.jpg to ~//OneDrive/git-repos/LCBP_Soils/Plots/
#
# Warning message:
# “Removed 1794 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1794 rows containing missing values or values outside the scale range (`geom_line()`).”
# plot without title

# %%
# 1. Define range and output path (if needed, NULL is okay)

event_window <- as.POSIXct(c("2022-02-10", "2026-02-25"), tz = "UTC")
plots_path <- "~//OneDrive/git-repos/LCBP_Soils/Plots/"

# 2. Run and save as jpg

hw2_plot <- plot_soil_sensors(
  df = HW2_78920_Table1, 
  df_name = "HW2_78920_Table1",
  sensor_types = c("VWC", "O2_Final_Avg", "SBTemp_C_Avg", "EC"), 
  time_range = event_window,
  output_dir = plots_path
)

print(hw2_plot)
# Out:
# Warning message:
# “Removed 31548 rows containing missing values or values outside the scale range (`geom_line()`).”
# Saved: HW2_78920_Table1_VWC_O2_Final_Avg_SBTemp_C_Avg_EC.jpg to ~//OneDrive/git-repos/LCBP_Soils/Plots/
#
# Warning message:
# “Removed 31548 rows containing missing values or values outside the scale range (`geom_line()`).”
# plot without title
